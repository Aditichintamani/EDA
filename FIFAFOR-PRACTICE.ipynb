# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('fifa.csv')

# %%
data.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
data.isnull().sum()
# Out:
# ID                              0
# Name                            0
# Age                             0
# Photo                           0
# Nationality                     0
# Flag                            0
# Overall                         0
# Potential                       0
# Club                          241
# Club Logo                       0
# Value                           0
# Wage                            0
# Preferred Foot                 48
# International Reputation       48
# Weak Foot                      48
# Skill Moves                    48
# Work Rate                      48
# Body Type                      48
# Position                       60
# Jersey Number                  60
# Joined                       1553
# Loaned From                 16943
# Contract Valid Until          289
# Height                         48
# Weight                         48
# Crossing                       48
# Finishing                      48
# ...

# %%
data.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Preferred Foot',
#        'International Reputation', 'Weak Foot', 'Skill Moves', 'Work Rate',
#        'Body Type', 'Position', 'Jersey Number', 'Joined', 'Loaned From',
#        'Contract Valid Until', 'Height', 'Weight', 'Crossing', 'Finishing',
#        'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve',
#        'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause'],
#       dtype='object')

# %%
data1=data[['Name', 'Age','Nationality','Overall','Potential', 'Club','Value', 'Wage','International Reputation','Work Rate','Position','Joined', 'Loaned From','Contract Valid Until', 'Height', 'Weight','Release Clause']]

# %%
data1.columns
# Out:
# Index(['Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club', 'Value',
#        'Wage', 'International Reputation', 'Work Rate', 'Position', 'Joined',
#        'Loaned From', 'Contract Valid Until', 'Height', 'Weight',
#        'Release Clause'],
#       dtype='object')

# %%
data1.isnull().sum()
# Out:
# Name                            0
# Age                             0
# Nationality                     0
# Overall                         0
# Potential                       0
# Club                          241
# Value                           0
# Wage                            0
# International Reputation       48
# Work Rate                      48
# Position                       60
# Joined                       1553
# Loaned From                 16943
# Contract Valid Until          289
# Height                         48
# Weight                         48
# Release Clause               1564
# dtype: int64

# %%
data1[data1['Club'].isnull()].head()
# Out:
#              Name  Age Nationality  Overall  Potential Club Value Wage  \
# 452    L. Paredes   24   Argentina       80         85  NaN    €0   €0
# 538  A. Granqvist   33      Sweden       80         80  NaN    €0   €0
# 568      A. Lunev   26      Russia       79         81  NaN    €0   €0
# 677  I. Smolnikov   29      Russia       79         79  NaN    €0   €0
# 874     A. Dzyuba   29      Russia       78         78  NaN    €0   €0
#
#      International Reputation       Work Rate Position Joined Loaned From  \
# 452                       2.0  Medium/ Medium       CM    NaN         NaN
# 538                       2.0    High/ Medium      LCB    NaN         NaN
# 568                       1.0  Medium/ Medium       GK    NaN         NaN
# 677                       2.0      High/ High       RB    NaN         NaN
# 874                       2.0    High/ Medium       ST    NaN         NaN
#
#     Contract Valid Until Height  Weight Release Clause
# ...

# %%
data1.drop('Club',axis=1,inplace=True)

# %%
data1.isnull().sum()
# Out:
# Name                            0
# Age                             0
# Nationality                     0
# Overall                         0
# Potential                       0
# Value                           0
# Wage                            0
# International Reputation       48
# Work Rate                      48
# Position                       60
# Joined                       1553
# Loaned From                 16943
# Contract Valid Until          289
# Height                         48
# Weight                         48
# Release Clause               1564
# dtype: int64

# %%
data1.shape[0]
# Out:
# 18207

# %%
#dat[dat['B'].notnull()]  
data1=data1[data1['International Reputation'].notnull()]

# %%
data1.isnull().sum()
# Out:
# Name                            0
# Age                             0
# Nationality                     0
# Overall                         0
# Potential                       0
# Value                           0
# Wage                            0
# International Reputation        0
# Work Rate                       0
# Position                       12
# Joined                       1505
# Loaned From                 16895
# Contract Valid Until          241
# Height                          0
# Weight                          0
# Release Clause               1516
# dtype: int64

# %%
data1=data1[data1['Contract Valid Until'].notnull()]

# %%
data1.isnull().sum()
# Out:
# Name                            0
# Age                             0
# Nationality                     0
# Overall                         0
# Potential                       0
# Value                           0
# Wage                            0
# International Reputation        0
# Work Rate                       0
# Position                        0
# Joined                       1264
# Loaned From                 16654
# Contract Valid Until            0
# Height                          0
# Weight                          0
# Release Clause               1275
# dtype: int64

# %%
data1.shape
# Out:
# (17918, 16)

# %%
#data1.Joined

# %%
data['Joined']=data['Joined'].astype('category')

# %%
data1['Joined'].fillna(data1['Joined'].mode()[0],inplace=True)

# %%
data
# Out:
#            ID                  Name  Age  \
# 0      158023              L. Messi   31
# 1       20801     Cristiano Ronaldo   33
# 2      190871             Neymar Jr   26
# 3      193080                De Gea   27
# 4      192985          K. De Bruyne   27
# 5      183277             E. Hazard   27
# 6      177003             L. Modrić   32
# 7      176580             L. Suárez   31
# 8      155862          Sergio Ramos   32
# 9      200389              J. Oblak   25
# 10     188545        R. Lewandowski   29
# 11     182521              T. Kroos   28
# 12     182493              D. Godín   32
# 13     168542           David Silva   32
# 14     215914              N. Kanté   27
# 15     211110             P. Dybala   24
# 16     202126               H. Kane   24
# 17     194765          A. Griezmann   27
# 18     192448         M. ter Stegen   26
# 19     192119           T. Courtois   26
# 20     189511       Sergio Busquets   29
# 21     179813             E. Cavani   31
# ...

# %%
k=[]
for i in data1.Joined.values:
    k.append(str(i).split(',')[1])

# %%
data1['YrJoined']=k

# %%
data1.drop('Joined',axis=1,inplace=True)

# %%
data1.rename({'YrJoined':'Joined'},axis=1,inplace=True)

# %%
data1.isnull().sum()
# Out:
# Name                            0
# Age                             0
# Nationality                     0
# Overall                         0
# Potential                       0
# Value                           0
# Wage                            0
# International Reputation        0
# Work Rate                       0
# Position                        0
# Loaned From                 16654
# Contract Valid Until            0
# Height                          0
# Weight                          0
# Release Clause               1275
# Joined                          0
# dtype: int64

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17918 entries, 0 to 18206
# Data columns (total 16 columns):
# Name                        17918 non-null object
# Age                         17918 non-null int64
# Nationality                 17918 non-null object
# Overall                     17918 non-null int64
# Potential                   17918 non-null int64
# Value                       17918 non-null object
# Wage                        17918 non-null object
# International Reputation    17918 non-null float64
# Work Rate                   17918 non-null object
# Position                    17918 non-null object
# Loaned From                 1264 non-null object
# Contract Valid Until        17918 non-null object
# Height                      17918 non-null object
# Weight                      17918 non-null object
# Release Clause              16643 non-null object
# Joined                      17918 non-null object
# dtypes: float64(1), int64(3), object(12)
# ...

# %%
data1['Loaned From'].fillna(data1['Loaned From'].mode()[0],inplace=True)

# %%
data1['Release Clause']=data1['Release Clause'].str.lstrip('€').str.rstrip('M')

# %%
data1['Release Clause']=data1['Release Clause'].str.rstrip('K')

# %%
data1['Release Clause'].fillna(data1['Release Clause'].median(),inplace=True)

# %%
data1['Release Clause']=data1['Release Clause'].astype(float)

# %%
data1.isnull().sum()
# Out:
# Name                        0
# Age                         0
# Nationality                 0
# Overall                     0
# Potential                   0
# Value                       0
# Wage                        0
# International Reputation    0
# Work Rate                   0
# Position                    0
# Loaned From                 0
# Contract Valid Until        0
# Height                      0
# Weight                      0
# Release Clause              0
# Joined                      0
# dtype: int64

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17918 entries, 0 to 18206
# Data columns (total 16 columns):
# Name                        17918 non-null object
# Age                         17918 non-null int64
# Nationality                 17918 non-null object
# Overall                     17918 non-null int64
# Potential                   17918 non-null int64
# Value                       17918 non-null object
# Wage                        17918 non-null object
# International Reputation    17918 non-null float64
# Work Rate                   17918 non-null object
# Position                    17918 non-null object
# Loaned From                 17918 non-null object
# Contract Valid Until        17918 non-null object
# Height                      17918 non-null object
# Weight                      17918 non-null object
# Release Clause              17918 non-null float64
# Joined                      17918 non-null object
# dtypes: float64(2), int64(3), object(11)
# ...

# %%
w=[]
for i in data1['Value']:
    w.append(float(i.strip('M').strip('€').strip('K')))

# %%
data1['value']=w

# %%
data1.drop('Value',axis=1,inplace=True)

# %%
data1.rename({'value':'Value'},inplace=True)

# %%
q=[]
for i in data1['Height']:
    q.append(float(i.replace('\'','.')))
#data1['Height'].str.replace('\'','.').astype(float)

# %%
data1['Height']=q

# %%
data1['Height'].dtype
# Out:
# dtype('float64')

# %%
data1['Weight']=data1['Weight'].str.strip('lbs')

# %%
data1['Release Clause'].dtype
# Out:
# dtype('float64')

# %%
data1['Joined']=pd.to_datetime(data1['Joined']).dt.year

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,10))
sns.countplot(data1['Overall'])
plt.show()

# %%
data1['Wage']=data1['Wage'].str.strip('K').str.strip('€')

# %%
col=['Overall','Value','Wage', 'International Reputation','Height','Weight','Release Clause']

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17918 entries, 0 to 18206
# Data columns (total 16 columns):
# Name                        17918 non-null object
# Age                         17918 non-null int64
# Nationality                 17918 non-null object
# Overall                     17918 non-null int64
# Potential                   17918 non-null int64
# Wage                        17918 non-null object
# International Reputation    17918 non-null float64
# Work Rate                   17918 non-null object
# Position                    17918 non-null object
# Loaned From                 17918 non-null object
# Contract Valid Until        17918 non-null object
# Height                      17918 non-null float64
# Weight                      17918 non-null object
# Release Clause              17918 non-null float64
# Joined                      17918 non-null int64
# value                       17918 non-null float64
# dtypes: float64(4), int64(4), object(8)
# ...

# %%
data1['Name']=data1['Name'].astype('category')
data1['Nationality']=data1['Nationality'].astype('category')
data1['Wage']=data1['Wage'].astype('float')
data1['Weight']=data1['Weight'].astype('float')
data1['Loaned From']=data1['Loaned From'].astype('category')

#data1['Contract Valid Until']=data1['Contract Valid Until'].astype('int')

# %%
data1['Contract Valid Until'].unique()
# Out:
# array(['2021', '2022', '2020', '2023', '2019', '2024', 'Jun 30, 2019',
#        '2025', '2026', 'Dec 31, 2018', '2018', 'May 31, 2020',
#        'Jun 30, 2020', 'May 31, 2019', 'Dec 31, 2019', 'Jan 1, 2019',
#        'Jun 1, 2019', 'Jan 4, 2019', 'Jan 31, 2019', 'Jan 7, 2019',
#        'Jan 2, 2019', 'Jan 6, 2019', 'Oct 14, 2019', 'Jan 3, 2019',
#        'May 4, 2019', 'Jan 12, 2019', 'Jan 25, 2019', 'Jan 18, 2019',
#        'Dec 1, 2019', 'Nov 30, 2018', 'Feb 27, 2020', 'Jan 5, 2019',
#        'Jan 15, 2019', 'Jan 30, 2019', 'Jan 11, 2019', 'Jan 20, 2019'],
#       dtype=object)

# %%
data1.drop('l',axis=1,inplace=True)

# %%
q=[]
for i in data1['Contract Valid Until']:
    if i.startswith('J') or i.startswith('F') or i.startswith('M') or i.startswith('A') or i.startswith('S') or i.startswith('N') or i.startswith('D') or i.startswith('O'):
        q.append(i.split(',')[1].lstrip(' ').rstrip(' '))
    else:
        q.append(i)

# %%
q=pd.Series(q)

# %%
q.shape
# Out:
# (17918,)

# %%
data1['ContractValid']=q

# %%
data3=data1[data1['ContractValid'].notnull()]

# %%
data1['ContractValid'].unique()
# Out:
# array(['2021', '2022', '2020', '2023', '2019', '2024', '2025', '2026',
#        '2018', nan], dtype=object)

# %% [markdown]
# 3.	Generate a table containing the top 20 players ranked by Overall score and whose contract expires in 2020.

# %%
data3['ContractValid']=data3['ContractValid'].astype('int')
# Out:
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data3[data3['ContractValid']==2020].sort_values(by='Overall',ascending=False).head(20)
# Out:
#                 Name  Age Nationality  Overall  Potential   Wage  \
# 3             De Gea   27       Spain       91         93  260.0
# 6          L. Modrić   32     Croatia       91         91  420.0
# 8       Sergio Ramos   32       Spain       91         91  380.0
# 5          E. Hazard   27     Belgium       91         91  340.0
# 13       David Silva   32       Spain       90         90  285.0
# 21         E. Cavani   31     Uruguay       89         89  200.0
# 24      G. Chiellini   33       Italy       89         89  215.0
# 31        C. Eriksen   26     Denmark       88         91  205.0
# 39      Thiago Silva   33      Brazil       88         88  165.0
# 50        D. Mertens   31     Belgium       87         87  135.0
# 52         M. Hamšík   30    Slovakia       87         87  125.0
# 49        Jordi Alba   29       Spain       87         87  250.0
# 46          K. Navas   31  Costa Rica       87         87  195.0
# ...

# %%
C=data3[data3['ContractValid']==2020]

# %%
C2020=C.sort_values(by='Overall',ascending=False).head(20)

# %% [markdown]
# ### a)	What would the average wage for this set of players be?

# %%
C2020['Wage'].mean()
# Out:
# 205.45

# %% [markdown]
# ### b)	What is the average age

# %%
C2020['Age'].mean()
# Out:
# 30.65

# %% [markdown]
# ### c)	Is there a correlation between the Overall rating and Value for these players?

# %%
C2020['Overall'].corr(C2020['value'])
# Out:
# 0.7867166042074151

# %% [markdown]
# ### 4.	Generate tables containing the top 5 players by Overall rating for each unique position.

# %%
top5=data3.sort_values(by='Overall',ascending=False).head()

# %%
data1=data3.sort_values(by=['Position','Overall'],ascending=False).groupby('Position',as_index=True)[['Name','Position','Overall']].head()

# %%
data1
# Out:
#                      Name Position  Overall
# 1       Cristiano Ronaldo       ST       94
# 10         R. Lewandowski       ST       90
# 16                H. Kane       ST       89
# 23              S. Agüero       ST       89
# 36                G. Bale       ST       88
# 450             M. Ginter      RWB       80
# 465          P. Kadeřábek      RWB       80
# 517            S. Coleman      RWB       80
# 652          D. Caligiuri      RWB       79
# 766          Pablo Maffeo      RWB       78
# 56         Bernardo Silva       RW       86
# 60            R. Sterling       RW       86
# 79          Marco Asensio       RW       85
# 84              R. Mahrez       RW       85
# 93             A. Sánchez       RW       85
# 7               L. Suárez       RS       91
# 109        Z. Ibrahimović       RS       85
# 148                Falcao       RS       84
# 267         W. Ben Yedder       RS       82
# 357               S. Zaza       RS       81
# ...
